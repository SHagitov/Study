# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = dict()
with open('26-96.txt') as f:
    N = int(f.readline())
    for _ in range(N):
        x, y = map(int, f.readline().split())
        d[y] = d.get(y, []) + [x // 10 if x >= 0 else -(abs(x) // 10)]

ans = [0, 0, 0]
ml = None
for x, y in sorted(d.items()):
    if len(y) >= ans[1]:
        ans = [x, len(y), len(set(y))]
print(ans[0], ans[2])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5456\1265581174.py in <module>
#       1 d = dict()
# ----> 2 with open('26-96.txt') as f:
#       3     N = int(f.readline())
#       4     for _ in range(N):
#       5         x, y = map(int, f.readline().split())
#
# FileNotFoundError: [Errno 2] No such file or directory: '26-96.txt'
